# %%
# 課題9：再帰的な関数でのフィボナッチ数列.ipynb で prognum.py をインポートしてください
import prognum

# 「何番目の数値を求めたいか」をキーボードから入力できるようにしてください。（数値が入力される前提でかまいませんので、例外処理は不要です）
# フィボナッチ数列を計算する関数を実行する命令を記述してください。キーボードから入力した数値を引数に指定しましょう
# 計算結果の数値を画面に出力してください
while True:
    num = input("何番目の数値を求めますか？（空欄で終了）：")
    if num == "":
        break  # ループを抜ける
    num = int(num)
    print(prognum.fib(num))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 # 「何番目の数値を求めたいか」をキーボードから入力できるようにしてください。（数値が入力される前提でかまいませんので、例外処理は不要です）
#       5 while True:
# ----> 6     num = input("何番目の数値を求めますか？（空欄で終了）：")
#       7     if num == "":
#       8         break  # ループを抜ける
#
# File ~/Downloads/pythondev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1260, in Kernel.raw_input(self, prompt)
#    1258     msg = "raw_input was called, but this frontend does not support input requests."
#    1259     raise StdinNotImplementedError(msg)
# -> 1260 return self._input_request(
#    1261     str(prompt),
#    1262     self._parent_ident["shell"],
#    1263     self.get_parent("shell"),
#    1264     password=False,
#    1265 )
#
# ...
